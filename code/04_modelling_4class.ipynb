# %% [markdown]
# <div align="center">
#
# # 04 — Ablasi Negative Anchor: Training 4-Kelas
#
# Notebook ini mereplikasi eksperimen `03_2` dengan menghapus kelas pengecoh (manhole & patchy_road).
# Tujuan: menguji apakah negative anchor class berkontribusi pada presisi deteksi Pothole.
# Dua model dijalankan: **YOLOv8n** (baseline) dan **YOLO-RD** (model terbaik 03_2).
#
# </div>

# %%
# # Jalankan sekali jika environment belum lengkap.
# # Setelah install selesai, restart kernel agar import library bersih.
# import subprocess, sys
# pkgs = [
#     "ultralytics>=8.3.0",
#     "opencv-python-headless",
#     "matplotlib",
#     "seaborn",
#     "pandas",
#     "numpy",
# ]
# subprocess.check_call([sys.executable, "-m", "pip", "install", "--quiet", *pkgs])
# print("Install selesai — restart kernel sekarang.")

# %%
import torch
print(f"torch version     : {torch.__version__}")
print(f"torch cuda build  : {torch.version.cuda}")
print(f"CUDA available    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU               : {torch.cuda.get_device_name(0)}")
# Out:
# torch version     : 2.6.0+cu124
# torch cuda build  : 12.4
# CUDA available    : True
# GPU               : NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %% [markdown]
# ## ***Konfigurasi Global***
#
# ---
#
# Satu cell ini berisi seluruh konstanta eksperimen. Ubah di sini, bukan di cell lain.

# %%
from pathlib import Path

# ── Reproducibility ──────────────────────────────────────────────────────────
SEED = 42

# ── Smoke test flag ──────────────────────────────────────────────────────────
# True  → 2 epoch, cepat untuk verifikasi pipeline
# False → 300 epoch, eksperimen final
SMOKE_TEST = True

# ── Paths ────────────────────────────────────────────────────────────────────
ROOT_CANDIDATES = [
    Path.cwd().resolve(),
    Path.cwd().resolve().parent,
    Path("D:/01_Akademik/TA-Project"),
]
REPO_ROOT = next(
    (p for p in ROOT_CANDIDATES if (p / "data").exists()),
    Path.cwd().resolve(),
)
# Dataset 6-kelas asli (hanya untuk referensi gambar via symlink)
SRC_DATASET_DIR = (
    REPO_ROOT
    / "data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes"
    / "RDD_Split_Final_china_japan_india_6_classes"
)
# Dataset 4-kelas — label sudah difilter (ID 4 & 5 dihapus), gambar symlink ke asli
DATASET_DIR = REPO_ROOT / "data/NRDD-2024/RDD_4class"
OUTPUT_DIR = REPO_ROOT / "runs/rdd_4class_local"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# ── Training hyperparameters ─────────────────────────────────────────────────
EPOCHS      = 2 if SMOKE_TEST else 300
PATIENCE    = 10 if SMOKE_TEST else 40
IMGSZ       = 640

# ── Focal loss ───────────────────────────────────────────────────────────────
FOCAL_GAMMA = 1.5

# ── Augmentasi ───────────────────────────────────────────────────────────────
MOSAIC       = 1.0
MIXUP        = 0.05
FLIPLR       = 0.5
TRANSLATE    = 0.10
SCALE        = 0.50
DEGREES      = 0.0   # Tidak menggunakan rotasi (arahan metodologi/dospem)
CLOSE_MOSAIC = 10

# ── Evaluasi ─────────────────────────────────────────────────────────────────
EVAL_CONF    = 0.001
EVAL_IOU     = 0.60
PRED_CONF    = 0.25
PRED_IOU     = 0.60

# ── Kelas dataset (4 kelas — tanpa manhole & patchy_road) ────────────────────
CLASS_NAMES = [
    "Longitudinal_Crack",
    "Transverse_Crack",
    "Alligator_Crack",
    "Pothole",
]

# ── Daftar model ─────────────────────────────────────────────────────────────
# kind:
#   "pretrained"  → spec adalah nama file .pt di code/ (atau nama yg di-download Ultralytics)
#   "yaml_custom" → spec adalah path yaml relatif terhadap REPO_ROOT
# Hanya yolov8n dan yolo_rd yang diaktifkan untuk perbandingan 6-class vs 4-class.
# Tiga model lain di-comment agar mudah diaktifkan kembali jika diperlukan.
MODELS = [
    # {"name": "yolov12n_4cls",  "spec": "yolo12n.pt",               "kind": "pretrained",  "batch": 16, "amp": True},
    # {"name": "yolov26n_4cls",  "spec": "yolo26n.pt",               "kind": "pretrained",  "batch": 16, "amp": True},
    # {"name": "yolov8_pd_4cls", "spec": "code/models/yolov8-pd.yaml", "kind": "yaml_custom", "batch": 16, "amp": False},
    {"name": "yolov8n_4cls",   "spec": "yolov8n.pt",               "kind": "pretrained",  "batch": 16, "amp": True},
    {"name": "yolo_rd_4cls",   "spec": "code/models/yolo-rd.yaml",  "kind": "yaml_custom", "batch": 8,  "amp": False},
]

# ── Verifikasi path ──────────────────────────────────────────────────────────
print(f"Repo root   : {REPO_ROOT}")
print(f"Dataset dir : {DATASET_DIR}")
print(f"Output dir  : {OUTPUT_DIR}")
print(f"Smoke test  : {SMOKE_TEST}  →  epochs={EPOCHS}, patience={PATIENCE}")
assert DATASET_DIR.exists(), f"Dataset tidak ditemukan: {DATASET_DIR}"
# Out:
# Repo root   : /run/media/varys/Data/01_Akademik/TA-Project
# Dataset dir : /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_4class
# Output dir  : /run/media/varys/Data/01_Akademik/TA-Project/runs/rdd_4class_local
# Smoke test  : True  →  epochs=2, patience=10

# %% [markdown]
# ## ***Imports dan Setup Awal***
#
# ---

# %%
import json
import os
import random
import sys
from collections import Counter

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import yaml
from IPython.display import Image, display

# Seed
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# GPU / CPU
print(f"Torch version       : {torch.__version__}")
print(f"CUDA available      : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device count   : {torch.cuda.device_count()}")
    print(f"Current GPU         : {torch.cuda.get_device_name(0)}")
    DEVICE = 0
    BATCH  = 16   # default; tiap model bisa override via MODELS[i]["batch"]
else:
    print("Training akan berjalan di CPU. Untuk 300 epoch, sangat disarankan memakai GPU.")
    DEVICE = "cpu"
    BATCH  = 4

# Windows notebook lebih stabil dengan workers=0
WORKERS = 0 if os.name == "nt" else 4
print(f"Device untuk YOLO   : {DEVICE}")
print(f"Batch default       : {BATCH}")
print(f"Dataloader workers  : {WORKERS}")
# Out:
# Torch version       : 2.6.0+cu124
# CUDA available      : True
# CUDA device count   : 1
# Current GPU         : NVIDIA GeForce RTX 3050 6GB Laptop GPU
# Device untuk YOLO   : 0
# Batch default       : 16
# Dataloader workers  : 4

# %% [markdown]
# ## ***Persiapan Dataset 4-Kelas***
#
# ---
#
# Dataset `RDD_4class` dibuat oleh script `code/prepare_4class_dataset.py`.
# **Jalankan script ini satu kali sebelum notebook ini dieksekusi**, terutama setelah `git pull` di mesin baru.
#
# ```bash
# python code/prepare_4class_dataset.py
# ```
#
# Yang dilakukan script:
# - Label file difilter — baris dengan class ID 4 (manhole) dan 5 (patchy_road) dihapus.
# - Gambar di-symlink ke dataset asli di Linux/Mac (tidak ada copy fisik).
# - Di Windows: dicoba symlink dulu, fallback ke copy otomatis jika Developer Mode tidak aktif.
# - File `data.yaml` dibuat di folder `data/NRDD-2024/RDD_4class/`.
#
# Cell berikut memverifikasi dataset sudah ada sebelum melanjutkan.

# %%
import yaml

# ── Verifikasi dataset 4-kelas sudah disiapkan ───────────────────────────────
_missing = []
for _split in ["train", "val", "test"]:
    _img = DATASET_DIR / _split / "images"
    _lbl = DATASET_DIR / _split / "labels"
    if not _img.exists(): _missing.append(str(_img))
    if not _lbl.exists(): _missing.append(str(_lbl))

if _missing:
    raise FileNotFoundError(
        "Dataset 4-kelas belum disiapkan. Jalankan dulu:\n"
        "  python code/prepare_4class_dataset.py\n\n"
        "Folder tidak ditemukan:\n" + "\n".join(f"  {p}" for p in _missing)
    )

print("Dataset 4-kelas terverifikasi:")
for _split in ["train", "val", "test"]:
    _n_img = len(list((DATASET_DIR / _split / "images").iterdir()))
    _n_lbl = len(list((DATASET_DIR / _split / "labels").glob("*.txt")))
    print(f"  {_split:5s}: {_n_img} gambar, {_n_lbl} label files")

# ── Buat rdd4_local.yaml di OUTPUT_DIR untuk logging ─────────────────────────
original_yaml = DATASET_DIR / "data.yaml"
with original_yaml.open("r", encoding="utf-8") as f:
    data_cfg = yaml.safe_load(f)

data_cfg["path"]  = str(DATASET_DIR.resolve()).replace("\\", "/")
data_cfg["train"] = "train/images"
data_cfg["val"]   = "val/images"
data_cfg["test"]  = "test/images"
data_cfg["nc"]    = len(CLASS_NAMES)
data_cfg["names"] = CLASS_NAMES

local_yaml = OUTPUT_DIR / "rdd4_local.yaml"
with local_yaml.open("w", encoding="utf-8") as f:
    yaml.safe_dump(data_cfg, f, sort_keys=False, allow_unicode=False)

print(f"\nYAML tersimpan: {local_yaml}")
print(local_yaml.read_text(encoding="utf-8"))
# Out:
# YAML tersimpan: /run/media/varys/Data/01_Akademik/TA-Project/runs/rdd_4class_local/rdd4_local.yaml
# path: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_4class
# train: train/images
# val: val/images
# test: test/images
# nc: 4
# names:
# - Longitudinal_Crack
# - Transverse_Crack
# - Alligator_Crack
# - Pothole

# %% [markdown]
# ## ***Audit Dataset***
#
# ---
#
# Audit jumlah gambar, label, objek, missing label, dan extra label sebelum training.
# Label file sudah bersih (ID 4 & 5 telah dihapus di preprocessing). Audit ini memverifikasi hasilnya.
# File `classes.txt` di folder labels diabaikan.

# %%
IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}


def list_images(split: str):
    image_dir = DATASET_DIR / split / "images"
    return sorted([p for p in image_dir.iterdir() if p.suffix.lower() in IMG_EXTS])


def list_label_files(split: str):
    label_dir = DATASET_DIR / split / "labels"
    return sorted([p for p in label_dir.glob("*.txt") if p.name.lower() != "classes.txt"])


def read_yolo_labels(label_path):
    rows = []
    for line_no, line in enumerate(
        label_path.read_text(encoding="utf-8", errors="ignore").splitlines(), start=1
    ):
        parts = line.strip().split()
        if not parts:
            continue
        if len(parts) != 5:
            rows.append({"file": label_path.name, "line": line_no, "error": "not_5_columns", "raw": line})
            continue
        try:
            class_id = int(parts[0])
            x, y, w, h = map(float, parts[1:])
        except ValueError:
            rows.append({"file": label_path.name, "line": line_no, "error": "parse_error", "raw": line})
            continue
        rows.append({"file": label_path.name, "line": line_no, "class_id": class_id,
                     "x": x, "y": y, "w": w, "h": h})
    return rows


summary_rows = []
label_rows   = []
invalid_rows = []

for split in ["train", "val", "test"]:
    images = list_images(split)
    labels = list_label_files(split)
    image_stems = {p.stem for p in images}
    label_stems = {p.stem for p in labels}

    split_counter = Counter({i: 0 for i in range(len(CLASS_NAMES))})
    split_objects = 0

    for lp in labels:
        for row in read_yolo_labels(lp):
            if "error" in row:
                invalid_rows.append({"split": split, **row})
                continue
            class_id = row["class_id"]
            # Hanya hitung kelas 0–3 (4-class); abaikan ID 4 & 5
            if class_id < 0 or class_id >= len(CLASS_NAMES):
                continue
            if not all(0.0 <= row[k] <= 1.0 for k in ["x", "y", "w", "h"]):
                invalid_rows.append({"split": split, "file": row["file"], "error": "bbox_out_of_0_1_range", **row})
                continue
            split_counter[class_id] += 1
            split_objects += 1
            label_rows.append({"split": split, "class_id": class_id, "class_name": CLASS_NAMES[class_id], **row})

    summary_rows.append({
        "split": split,
        "images": len(images),
        "labels": len(labels),
        "objects": split_objects,
        "missing_label_files": len(image_stems - label_stems),
        "extra_label_files": len(label_stems - image_stems),
    })

summary_df  = pd.DataFrame(summary_rows)
labels_df   = pd.DataFrame(label_rows)
invalid_df  = pd.DataFrame(invalid_rows)

class_df = (
    labels_df.groupby(["split", "class_id", "class_name"])
    .size().rename("objects").reset_index()
)
class_pivot = class_df.pivot_table(
    index=["class_id", "class_name"], columns="split", values="objects", fill_value=0
).reset_index()
for col in ["train", "val", "test"]:
    if col not in class_pivot.columns:
        class_pivot[col] = 0
class_pivot["total"]   = class_pivot[["train", "val", "test"]].sum(axis=1)
class_pivot["percent"] = class_pivot["total"] / class_pivot["total"].sum() * 100

print("Summary split:")
display(summary_df)
print("Distribusi kelas (4 kelas aktif):")
display(class_pivot[["class_id", "class_name", "train", "val", "test", "total", "percent"]])

class_pivot.to_csv(OUTPUT_DIR / "dataset_class_distribution_4cls.csv", index=False)
summary_df.to_csv(OUTPUT_DIR / "dataset_split_summary_4cls.csv", index=False)
# Out:
# Summary split:
#    split  images  labels  objects  missing_label_files  extra_label_files
# 0  train    6777    6777    14351                    0                  0
# 1    val    1898    1898     3996                    0                  0
# 2   test     995     995     2035                    0                  0
# Distribusi kelas (4 kelas aktif):
# split  class_id          class_name   train     val   test   total    percent
# 0             0  Longitudinal_Crack  4555.0  1257.0  635.0  6447.0  31.630851
# 1             1    Transverse_Crack  3219.0   897.0  446.0  4562.0  22.382494
# 2             2     Alligator_Crack  4385.0  1245.0  642.0  6272.0  30.772250
# 3             3             Pothole  2192.0   597.0  312.0  3101.0  15.214405

# %% [markdown]
# ### ***Visualisasi Distribusi Kelas***

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

splits_plot = ["train", "val", "test"]
x = np.arange(len(CLASS_NAMES))
width = 0.25
for i, split in enumerate(splits_plot):
    axes[0].bar(x + i * width, class_pivot[split], width, label=split)
axes[0].set_xticks(x + width)
axes[0].set_xticklabels(class_pivot["class_name"], rotation=25, ha="right")
axes[0].set_title("Jumlah objek per kelas per split (4-kelas)")
axes[0].set_ylabel("Jumlah objek")
axes[0].legend()

max_count = class_pivot["train"].max()
min_count = class_pivot["train"].replace(0, np.nan).min()
imbalance_ratio = max_count / min_count if min_count and min_count > 0 else float("nan")
axes[1].bar(class_pivot["class_name"], class_pivot["percent"], color="steelblue")
axes[1].set_xticklabels(class_pivot["class_name"], rotation=25, ha="right")
axes[1].set_title(f"Distribusi kelas train (imbalance ratio = {imbalance_ratio:.1f}x)")
axes[1].set_ylabel("Persentase (%)")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_48836/2806052846.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   axes[1].set_xticklabels(class_pivot["class_name"], rotation=25, ha="right")

# %% [markdown]
# ## ***Training (Loop)***
#
# ---
#
# Loop melakukan iterasi pada `MODELS`. Setiap model:
# 1. Disiapkan dengan Class-Balanced weighting (Cui et al., CVPR 2019) via patch `DetectionModel.init_criterion`.
# 2. Untuk `kind == "yaml_custom"`: load arsitektur dari YAML, lalu transfer bobot COCO via `.load("yolov8n.pt")`.
# 3. Untuk `kind == "pretrained"`: `YOLO(spec)` biasa.
# 4. Output tersimpan di `runs/rdd_4class_local/experiments/<run_name>/`.

# %%
CUSTOM_DIR = REPO_ROOT / "code/models"

HAS_CUSTOM = any(m["kind"] == "yaml_custom" for m in MODELS)
if HAS_CUSTOM:
    sys.path.insert(0, str(CUSTOM_DIR))
    from custom_modules import patch_ultralytics
    patch_ultralytics()
    print("patch_ultralytics() dipanggil — modul custom terdaftar.")


import gc
import yaml
import numpy as np
from pathlib import Path
from collections import Counter
from ultralytics import YOLO
from ultralytics.nn.tasks import DetectionModel
from ultralytics.utils.loss import v8DetectionLoss, E2ELoss


def count_class_instances(data_yaml_path, split="train"):
    """Scan file label YOLO-format (.txt) pada split tertentu, hitung jumlah
    instance per kelas (list sepanjang nc, terurut sesuai data.yaml)."""
    data_yaml_path = Path(data_yaml_path)
    with open(data_yaml_path) as f:
        cfg = yaml.safe_load(f)
    base = Path(cfg.get("path", data_yaml_path.parent))
    if not base.is_absolute():
        base = data_yaml_path.parent / base
    split_val = cfg[split]
    img_dirs = [split_val] if isinstance(split_val, str) else list(split_val)
    nc = cfg["nc"]
    counts = Counter({i: 0 for i in range(nc)})
    for img_dir in img_dirs:
        label_dir_path = Path(str(base / img_dir).replace("images", "labels"))
        for txt_file in label_dir_path.rglob("*.txt"):
            if txt_file.name.lower() == "classes.txt":
                continue
            with open(txt_file) as f:
                for line in f:
                    line = line.strip()
                    if line:
                        cid = int(line.split()[0])
                        if cid in counts:   # hanya hitung ID dalam nc=4
                            counts[cid] += 1
    return [counts[i] for i in range(nc)]


def effective_number_weights(counts, beta=0.999):
    """Class-Balanced weighting via Effective Number of Samples.
    Cui, Y., Jia, M., Lin, T-Y., Song, Y., & Belongie, S. (2019).
    "Class-Balanced Loss Based on Effective Number of Samples." CVPR 2019.
    https://arxiv.org/abs/1901.05555
    """
    counts_arr = np.clip(np.array(counts, dtype=np.float64), 1, None)
    effective_num = 1.0 - np.power(beta, counts_arr)
    weights = (1.0 - beta) / effective_num
    weights = weights / weights.sum() * len(counts_arr)
    return torch.tensor(weights, dtype=torch.float32)


print("Menghitung distribusi kelas dari dataset training...")
CLASS_COUNTS = count_class_instances(local_yaml, split="train")
CLASS_WEIGHTS = effective_number_weights(CLASS_COUNTS, beta=0.999)
print(f"Jumlah per kelas : {CLASS_COUNTS}")
print(f"Class weights    : {[round(w, 3) for w in CLASS_WEIGHTS.tolist()]}")


def _init_criterion_with_class_weights(self):
    """Patch di level CLASS DetectionModel — berlaku otomatis untuk semua
    model (YOLOv8n, YOLO-RD) karena Trainer membangun ulang model dari nol
    di dalam `.train()`."""
    if getattr(self, "class_weights", None) is None:
        self.class_weights = CLASS_WEIGHTS.to(next(self.parameters()).device)
    if getattr(self, "end2end", False):
        return E2ELoss(self)
    return v8DetectionLoss(self)

DetectionModel.init_criterion = _init_criterion_with_class_weights

# Verifikasi class_weights aktif
_dummy = YOLO("yolov8n.pt")
_dummy.model.train()
_crit = _dummy.model.init_criterion()
assert torch.allclose(_crit.class_weights.cpu(), CLASS_WEIGHTS), "class_weights tidak aktif!"
print(f"Class-balanced weighting terverifikasi aktif (beta=0.999, sumber: Cui et al. CVPR 2019)")
del _dummy, _crit
# Out:
# patch_ultralytics() dipanggil — modul custom terdaftar.
# Menghitung distribusi kelas dari dataset training...
# Jumlah per kelas : [4555, 3219, 4385, 2192]
# Class weights    : [0.965, 0.994, 0.967, 1.074]
# Class-balanced weighting terverifikasi aktif (beta=0.999, sumber: Cui et al. CVPR 2019)

# %%
# Utility VRAM flush — dijalankan sekali sebelum loop training jika diperlukan.
# Jika cell sebelumnya sempat load model dan gagal, jalankan cell ini terlebih dahulu.
try:
    del model
except NameError:
    pass
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    mem_free = torch.cuda.mem_get_info()[0] / 1024**3
    print(f"GPU VRAM bebas: {mem_free:.2f} GB")
# Out:
# GPU VRAM bebas: 5.57 GB

# %%
PROJECT_DIR  = OUTPUT_DIR / "experiments"
trained_runs = []  # daftar (model_name, run_name) untuk cell evaluasi

for m in MODELS:
    run_name = f"{m['name']}_smoke" if SMOKE_TEST else m["name"]
    print(f"\n{'='*60}")
    print(f"Training: {run_name}")
    print(f"{'='*60}")

    if m["kind"] == "yaml_custom":
        spec_path = REPO_ROOT / m["spec"]
        model = YOLO(str(spec_path), task="detect")
        model.load(str(REPO_ROOT / "code/yolov8n.pt"))
    else:
        # pretrained: coba resolve dari code/ dulu, fallback ke auto-download
        spec_path_local = REPO_ROOT / "code" / m["spec"]
        spec = str(spec_path_local) if spec_path_local.exists() else m["spec"]
        model = YOLO(spec)

    batch_size = m.get("batch", BATCH)
    amp_flag   = m.get("amp", True)

    model.train(
        data=str(local_yaml),
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=batch_size,
        device=DEVICE,
        workers=WORKERS,
        project=str(PROJECT_DIR),
        name=run_name,
        exist_ok=True,
        seed=SEED,
        deterministic=True,
        optimizer="auto",
        patience=PATIENCE,
        cache=False,
        amp=amp_flag,
        cos_lr=True,
        plots=True,
        save=True,
        save_period=25,
        close_mosaic=CLOSE_MOSAIC,
        mosaic=MOSAIC,
        mixup=MIXUP,
        fliplr=FLIPLR,
        translate=TRANSLATE,
        scale=SCALE,
        degrees=DEGREES,
    )

    trained_runs.append((m["name"], run_name))
    print(f"Selesai: {run_name}")

    # Bebaskan VRAM sebelum model berikutnya
    del model
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        mem_free = torch.cuda.mem_get_info()[0] / 1024**3
        print(f"  GPU VRAM bebas setelah cleanup: {mem_free:.2f} GB")

print("\nSemua model selesai ditraining:", trained_runs)
# Out:
# ============================================================
# Training: yolov8n_4cls_smoke
# ============================================================
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5804MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/run/media/varys/Data/01_Akademik/TA-Project/runs/rdd_4class_local/rdd4_local.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=2, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.05, mode=train, model=/run/media/varys/Data/01_Akademik/TA-Project/code/yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov8n_4cls_smoke, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/run/media/varys/Data/01_Akademik/TA-Project/runs/rdd_4class_local/experiments, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/run/media/varys/Data/01_Akademik/TA-Project/runs/rdd_4class_local/experiments/yolov8n_4cls_smoke, save_frames=False, save_json=False, save_period=25, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.0 ms, read: 307.4±84.9 MB/s, size: 66.3 KB)
# train: Scanning /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/labels.cache... 6777 images, 0 backgrounds, 1865 corrupt: 100% ━━━━━━━━━━━━ 6777/6777 1.4Git/s 0.0s
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000000_jpg.rf.f55a43351e43770bb4d1b90204b7e588.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000003_jpg.rf.592673fe43885987c5ff5e38d5bebe20.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000004_jpg.rf.bbde06e64d78395741a9e5fd706bf305.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000040_jpg.rf.22831e4cee69c4beca2f70448ffbda9d.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000051_jpg.rf.70dc250a72e084baad0ea97c9bad2c36.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000070_jpg.rf.f4c7da4114ef1c4b58ea13aab8a8d77c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000073_jpg.rf.313659d9d919be53548385e0365f895e.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000085_jpg.rf.dcad58e4200680553b63c23361c8b94f.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000087_jpg.rf.91318f067a872d0645df8532e7994805.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000090_jpg.rf.d77a97df2cb976e65d18153a991eeee6.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000091_jpg.rf.82deb2d0f215bc4e7c26b2c0c1179d39.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000097_jpg.rf.7e871bb802e5dd14e2c9f8e4bceda35b.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000107_jpg.rf.9e975699c11554143e33d89e4dabe1d7.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000111_jpg.rf.ecc785bd5fb01a13a73cc549350d73ec.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000127_jpg.rf.0bf870443d8385ff4452bae5b0861376.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000132_jpg.rf.e45705f9f410c6863a4d46762ab61c5b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000138_jpg.rf.dacd364599bf4f6f861eb7fe1e903f29.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000142_jpg.rf.518fccfa4fccdbc887a864821a74960b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000151_jpg.rf.945d9a7294d1a535cf0894ea78b5d4aa.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000172_jpg.rf.1090da2a43429435d24ec64c506fb28c.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000183_jpg.rf.01a77cf5a7e6b01ceb7661882458d90d.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000186_jpg.rf.1df804e044fd16de092b5ad12d5acf17.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000188_jpg.rf.6c592efdaf238b22c70216e710c2ffe2.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000190_jpg.rf.040115e3c30824ed377b70b87cb35a66.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000195_jpg.rf.be1700054ce9f6e386ed594bc1378399.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000199_jpg.rf.a7189c43a210135bdedab72926b50a96.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000201_jpg.rf.d7f4248597daf39d268654fa95f3df36.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000206_jpg.rf.e27705d20ad983220aa900d8de7cca01.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000210_jpg.rf.cc61882ca36c7b5493409ced728ac06b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000220_jpg.rf.c4f09423b3c3e68cb9c212d85e8a01ce.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000222_jpg.rf.66b52323c7f9e02c1ec474994143f1bd.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000230_jpg.rf.366984f9dc232d26c4874ec4137ef89a.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000235_jpg.rf.d0b5db39f42fd0c46cc80d17f6877c4b.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000242_jpg.rf.512438261da57c9703e132a03ab4d6d8.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000247_jpg.rf.3630fba13b1a416e8156caffbd1cab0b.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000257_jpg.rf.0d65b8b0dc2b936a482b392890f245c6.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000263_jpg.rf.e06c013784a2f2e64ccb56bb590ddcd8.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000268_jpg.rf.ef6533463bdf9c81ec86f54c104159a8.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000283_jpg.rf.60aaa86af427b57c7b8a5f37f0e9b59b.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000293_jpg.rf.d49774d7358c2cfa5d0eefbac6e1a1e9.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000294_jpg.rf.0c6029bc85c79453e03067d5f110f1af.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000296_jpg.rf.fb31e07177e31c557e27ff41271c3add.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000298_jpg.rf.b18d30162067f61843717d8cf13054e9.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000312_jpg.rf.ca1c225e657d16f53bcb7146c2b7c06d.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000319_jpg.rf.4520ea558fe3b65ae8a30d018cbfca5d.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000321_jpg.rf.06c0e9bd07f0d6c2032b89f893660dd5.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000322_jpg.rf.31b76bcdd2bd0442eafd8b5875cd3a9a.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000332_jpg.rf.dc5cb8e5b521f9ede71c70c60be41cf9.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000334_jpg.rf.becae5873714a1f1957ca1c61757e7a0.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000336_jpg.rf.6a6e03de8c963da0ed2999907fe64474.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000357_jpg.rf.bed5555db2e42ce2bf1548f635241900.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000366_jpg.rf.b5adee9799909b6b4b4ab8e91a803b1b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000369_jpg.rf.ae6174c394d6714bcfee1507c52884e1.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000387_jpg.rf.e59c0080c273289f3efa52b6d2c1226d.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000393_jpg.rf.404d2080642e262507231718ab3a438c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000394_jpg.rf.6929bd5e01416bb0989ddc6db7ab1c67.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000395_jpg.rf.6a83ec72aa4033498a0e34dbdccb58b8.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000397_jpg.rf.812508c59af6b883dbbbfa89f2aa3f63.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000402_jpg.rf.e56165e2131031cedfb0b229cf8d57f8.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000406_jpg.rf.57146b7f29ea9ba0e2a4853d86503ff3.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000434_jpg.rf.5170da4dac0a29160b07e9d460d0a452.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000442_jpg.rf.f9500153326c83a5d03308dedffb090c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000454_jpg.rf.582d69fffc7734f2559d59b96a5c38ed.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000469_jpg.rf.ac893f3c65883174fbdb82476ef94415.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000473_jpg.rf.237be9133c59c2bd9659829c96a20df7.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000495_jpg.rf.40b2587507c9015c472d5ff3abfafdde.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000524_jpg.rf.5a832d251022f330dd7bd2f9e16eeb28.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000542_jpg.rf.5bad6484d124b75771a8de42ac7375b4.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000553_jpg.rf.483957b6b74ae03557cc9b397c916aab.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000563_jpg.rf.77b81ae0590bf96aba8e571eb2130472.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000567_jpg.rf.468baaaefef11d7b7f09c50d8396b2de.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000579_jpg.rf.ad71e446f9ad6dd811297af865fce022.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000582_jpg.rf.838aedeff4c41f9b3f6762c264ca5e8a.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000619_jpg.rf.46e3d5d590e5e3c37c4d79e5c43c6509.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000645_jpg.rf.1811b49abb306fd0c49a889e175535f4.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000647_jpg.rf.1cec8a18732bc073418809b8a8f1f899.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000648_jpg.rf.bc9308c857ebe5d8aba755f52f3a582c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000691_jpg.rf.585c60068fadaca05b4e47d422c34c0f.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000707_jpg.rf.4aaebfc2315ac4e7624ccd1248909c4a.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000736_jpg.rf.120aba25cb9b303665c1b324bf9dbaca.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000801_jpg.rf.ca519b8c3099a97875d312ad88e0329e.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000815_jpg.rf.1673005f470f8eb6a22818e4f51609e0.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000819_jpg.rf.3b2a5db8a0401e6d3ddca1d17513678b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000834_jpg.rf.f987dbf2597f60d67917d25ddac998f0.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000856_jpg.rf.fabe83144631b0387e284be565be577b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000899_jpg.rf.910f74a5696aeb857a2dc7dadaba44a4.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000902_jpg.rf.d7ebdc43eeb23dbe14c21d3e7f276b9f.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000905_jpg.rf.8f8837caf2ac01f808576b0a5a167e6b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000920_jpg.rf.bb17fb2af3c626b1e9ebd3ff1d1bbae4.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000957_jpg.rf.2e61df844e1e74997d43ecb5b1bc0491.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000971_jpg.rf.d3c4becb7bf9a9a89a40be086c600868.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000976_jpg.rf.3b2004fde05f3b74d76535ba2179875d.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_000998_jpg.rf.4560c0a5d3015aeeeabeeb7d9bebcbca.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001016_jpg.rf.33c4508eeb34ad5b057ee82995838f2c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001033_jpg.rf.d77d5caf5d54930d4c66019b050c602c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001038_jpg.rf.aec6b016d79f870591b7effbfc244ce5.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001040_jpg.rf.1529a1862348110275da79a9640d09e0.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001041_jpg.rf.adbb1df007f2d88f695c4c7cb974a158.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001044_jpg.rf.6d9d2fd95af650eb6f1547c998c034d0.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001047_jpg.rf.351fb67db7dbb6e502e1b4978117bcae.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001050_jpg.rf.5d49e0bb42ebef59558ab835f151a3f7.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001056_jpg.rf.c7795f466c1049afa5bbe3bdf3f10c1b.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001059_jpg.rf.b055d8d19fb834125d0ab7caebb13c56.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001061_jpg.rf.9d18f199496e319dbb7d76deb5001d9d.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001068_jpg.rf.b34267ffe6aea26b2acd6596e4193120.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001073_jpg.rf.78d29cc3de0d31f3c9edc2c2b09c5b82.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001075_jpg.rf.c3ad792ff72846e404a73a3d73a166a5.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001076_jpg.rf.aea2300ba7b53a84c0068140adec463a.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001090_jpg.rf.41ca6c8a3b8963d387ea191c36dda1ba.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001107_jpg.rf.eabb28b5b17534b07bb8c885b6b17e02.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001108_jpg.rf.4ed6937da933a6d1f6593b5e523c1c7f.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001120_jpg.rf.039613dd7a19374fcd1247b47285a664.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001121_jpg.rf.1819ba037d6410b7a7f48d625f4ffd2a.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001126_jpg.rf.b70be7f9cdb04f95946caaaa4162893c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001139_jpg.rf.3fa5283f5b0729cfb355816cdc60f5ae.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001152_jpg.rf.5c454444a6442a8291c0c998aab0714b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001195_jpg.rf.ffc46d082e6552b9640a4313896371e0.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001204_jpg.rf.5179d02df14f5a7c862cbcc2fb6c6f20.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001223_jpg.rf.9ec29909ffefd02e2c20257b81aedbe6.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001224_jpg.rf.7e522543120068ea839d04bf227e4be4.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001230_jpg.rf.ba1b990af4fd2aa51c0656bbcb1808bd.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001231_jpg.rf.eed80f9064fede2c9b9e742e20bf4038.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001233_jpg.rf.2f23f4432e469ead56e22f039d594073.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# train: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/train/images/China_MotorBike_001244_jpg.rf.1d11e3d21bbc38ca2cce68251f687c9f.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# ...
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011602_jpg.rf.04ab132a9a6f8f76de5490aa828b72eb.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011610_jpg.rf.b10fee6717b77824664e6c491a4d0286.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011697_jpg.rf.47e6bf52a08e41c15c0435d7b98f658c.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011698_jpg.rf.a35bff0d82c9badf690b40c0cfe55b63.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011731_jpg.rf.ef711a3f69b1aad1c2a6921dcca43368.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011746_jpg.rf.e2ce4fd3b2b2bfe163a7a5245353a1c4.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011761_jpg.rf.2ba2467539f3f74ab33792d572c58f17.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011822_jpg.rf.c87d83553b0b2563ab94eb7c0b6b51bf.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011931_jpg.rf.b031c5f107dd9ffa9626888045b45172.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011958_jpg.rf.eecb2beeff7668dc97aa5602ff494bad.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_011967_jpg.rf.70a47d6017ce869ea60021a86818cfa7.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012043_jpg.rf.54950b3dbd546e1fcaf1a156d5d49bdf.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012101_jpg.rf.43a95450c6211d2b9f4b3148bda119c7.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012131_jpg.rf.91df24f4e7ec3ed1ab4192b251a23d16.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012133_jpg.rf.42ba2bc3d25b605ff9871162d09d1497.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012136_jpg.rf.cf1907bfee4008d56c021dd964072302.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012148_jpg.rf.2ac9f376151fddecefccc5797a1a1950.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012151_jpg.rf.19401c14a18f187afc7d0817d7267551.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012175_jpg.rf.a3acb7d0c710ecbc230a7183316eb802.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012244_jpg.rf.d18b1e0046972be367de53653dd88e03.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012246_jpg.rf.1080eee277cd23ecbb5a6cc130c3916e.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012301_jpg.rf.12508fd62519b5b8cf0e503ec0798425.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012326_jpg.rf.cf379ff48a432960b8bba2e4cf4099f4.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012357_jpg.rf.79f439e9933615eafd70bf0150d3860e.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012364_jpg.rf.0dba6a81e77f68d994f6a81fdaac4fda.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012378_jpg.rf.57749451521670e251ed831d60a5c895.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012383_jpg.rf.5cac86fac8798ab871e212707626db41.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012387_jpg.rf.139c6af4e4470d3fb069b598f8a11914.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012390_jpg.rf.cd5cf9e38e2f7313503990f8f9fea2d9.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012432_jpg.rf.3bcc185e7f0814e39087ea4640ab89fa.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012464_jpg.rf.7a5db894461abbdee6fbe01acd43b77b.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012494_jpg.rf.7488d2e43649067a55ff1d1b3b73b5ba.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012578_jpg.rf.616456db0ec039b1404893f1042aefb4.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012590_jpg.rf.ee8a8c3a0aa19ccd5308f5754561078f.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012630_jpg.rf.4a516db76fc9195719b15110d5049f8d.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012652_jpg.rf.1e1219a27b4b2abb2909cdb689b4bf74.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012682_jpg.rf.7ecf7ffc95278928e7e8de9d6916d03c.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012784_jpg.rf.9a9f57614e0186ea681b9a93cf41dc39.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012785_jpg.rf.992e3d59c1e09af252af8269080e63a8.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012795_jpg.rf.91180f06bc9d0fbf7ed35e88e600dea8.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012815_jpg.rf.ff7b903180d67e6939cac4f4d8095e49.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012828_jpg.rf.52cbe0eae28812d6036ecb70bfb9d5d9.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012848_jpg.rf.2a14356bf0ae41bcbc9840af8ce711c0.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012851_jpg.rf.91a448d1df1b70611a0a1d4d9452cc33.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012955_jpg.rf.341e48170990327259847a76babc330f.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_012987_jpg.rf.5d8465ab7e23662e792178e976940034.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_013009_jpg.rf.216ec87c74a78a5f1269351b217e49f8.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /run/media/varys/Data/01_Akademik/TA-Project/data/NRDD-2024/RDD_Split_Final_china_japan_india_6_classes/RDD_Split_Final_china_japan_india_6_classes/val/images/Japan_013099_jpg.rf.f3b8ac444b9ee87166b7224cca3e6cef.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...

# %% [markdown]
# ## ***Evaluasi per Model***
#
# ---
#
# Evaluasi val dan test untuk setiap model. Output disimpan di `runs/rdd_4class_local/evaluation/` dengan prefix nama model.

# %%
# Jika modul custom diperlukan saat load best.pt, patch harus sudah aktif.
if HAS_CUSTOM and "patch_ultralytics" not in dir():
    sys.path.insert(0, str(CUSTOM_DIR))
    from custom_modules import patch_ultralytics
    patch_ultralytics()

EVAL_DIR     = OUTPUT_DIR / "evaluation"
eval_results = {}  # model_name → {"val": metrics, "test": metrics}

for model_name, run_name in trained_runs:
    best_weights = PROJECT_DIR / run_name / "weights/best.pt"
    assert best_weights.exists(), f"best.pt tidak ditemukan: {best_weights}"

    best_model = YOLO(str(best_weights))

    print(f"\nEvaluasi {model_name} — val")
    val_metrics = best_model.val(
        data=str(local_yaml),
        split="val",
        imgsz=IMGSZ,
        batch=BATCH,
        device=DEVICE,
        workers=WORKERS,
        project=str(EVAL_DIR),
        name=f"{model_name}_val",
        exist_ok=True,
        plots=True,
        save_json=True,
        conf=EVAL_CONF,
        iou=EVAL_IOU,
    )

    print(f"\nEvaluasi {model_name} — test")
    test_metrics = best_model.val(
        data=str(local_yaml),
        split="test",
        imgsz=IMGSZ,
        batch=BATCH,
        device=DEVICE,
        workers=WORKERS,
        project=str(EVAL_DIR),
        name=f"{model_name}_test",
        exist_ok=True,
        plots=True,
        save_json=True,
        conf=EVAL_CONF,
        iou=EVAL_IOU,
    )

    eval_results[model_name] = {"val": val_metrics, "test": test_metrics}
    print(f"  val  mAP50: {val_metrics.results_dict.get('metrics/mAP50(B)', float('nan')):.4f}")
    print(f"  test mAP50: {test_metrics.results_dict.get('metrics/mAP50(B)', float('nan')):.4f}")

# %% [markdown]
# ### ***Metrik Per Kelas dan F1 Summary***

# %%
def per_class_metrics(metrics, class_names):
    rows = []
    box  = metrics.box
    for class_id, class_name in enumerate(class_names):
        try:
            precision, recall, ap50, ap5095 = box.class_result(class_id)
        except Exception:
            precision, recall, ap50, ap5095 = np.nan, np.nan, np.nan, np.nan
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0.0
        rows.append({
            "class_id":   class_id,
            "class_name": class_name,
            "precision":  float(precision),
            "recall":     float(recall),
            "f1":         float(f1),
            "mAP50":      float(ap50),
            "mAP50-95":   float(ap5095),
        })
    return pd.DataFrame(rows)


def safe_weighted_mean(values, weights):
    values  = np.asarray(values,  dtype=float)
    weights = np.asarray(weights, dtype=float)
    valid   = np.isfinite(values) & np.isfinite(weights)
    if not valid.any() or weights[valid].sum() == 0:
        return float("nan")
    return float(np.average(values[valid], weights=weights[valid]))


for model_name, run_name in trained_runs:
    val_metrics  = eval_results[model_name]["val"]
    test_metrics = eval_results[model_name]["test"]

    val_per_class  = per_class_metrics(val_metrics,  CLASS_NAMES)
    test_per_class = per_class_metrics(test_metrics, CLASS_NAMES)

    val_per_class = val_per_class.merge(
        class_pivot[["class_id", "val"]].rename(columns={"val": "support"}),
        on="class_id", how="left",
    )
    test_per_class = test_per_class.merge(
        class_pivot[["class_id", "test"]].rename(columns={"test": "support"}),
        on="class_id", how="left",
    )

    f1_summary = {
        "val_macro_f1":    float(val_per_class["f1"].mean()),
        "val_weighted_f1": safe_weighted_mean(val_per_class["f1"], val_per_class["support"]),
        "test_macro_f1":   float(test_per_class["f1"].mean()),
        "test_weighted_f1": safe_weighted_mean(test_per_class["f1"], test_per_class["support"]),
    }
    f1_summary_df = pd.DataFrame([f1_summary])

    print(f"\n{'─'*50}")
    print(f"Model: {model_name}")
    print("F1 summary:")
    display(f1_summary_df)
    print("Test per-class metrics:")
    display(test_per_class)

    # Simpan CSV per model
    val_per_class.to_csv(OUTPUT_DIR  / f"{model_name}_val_per_class_metrics.csv",  index=False)
    test_per_class.to_csv(OUTPUT_DIR / f"{model_name}_test_per_class_metrics.csv", index=False)
    f1_summary_df.to_csv(OUTPUT_DIR  / f"{model_name}_f1_summary.csv",             index=False)

    # Simpan summary JSON per model
    speed_total_ms = sum(
        float(v) for k, v in test_metrics.speed.items()
        if k in ["preprocess", "inference", "postprocess"]
    )
    summary = {
        "model":      model_name,
        "run_name":   run_name,
        "weights":    str(PROJECT_DIR / run_name / "weights/best.pt"),
        "data_yaml":  str(local_yaml),
        "nc":         len(CLASS_NAMES),
        "class_names": CLASS_NAMES,
        "imgsz":      IMGSZ,
        "epochs":     EPOCHS,
        "focal_gamma": FOCAL_GAMMA,
        "val_results":  {k: float(v) for k, v in val_metrics.results_dict.items()},
        "test_results": {k: float(v) for k, v in test_metrics.results_dict.items()},
        "f1_summary":   f1_summary,
        "test_speed_ms_per_image": {k: float(v) for k, v in test_metrics.speed.items()},
        "test_fps_estimate": 1000.0 / speed_total_ms if speed_total_ms > 0 else None,
    }
    with (OUTPUT_DIR / f"{model_name}_summary.json").open("w", encoding="utf-8") as f:
        json.dump(summary, f, indent=2)

    print(json.dumps(summary, indent=2))

# %% [markdown]
# ### ***Confusion Matrix / PR Curve / F1 Curve per Model***

# %%
for model_name, run_name in trained_runs:
    print(f"\n{'─'*50}")
    print(f"Model: {model_name}")
    for split in ["val", "test"]:
        eval_subdir = EVAL_DIR / f"{model_name}_{split}"
        for plot_file in [
            "confusion_matrix.png",
            "confusion_matrix_normalized.png",
            "PR_curve.png",
            "F1_curve.png",
        ]:
            plot_path = eval_subdir / plot_file
            if plot_path.exists():
                print(f"  {split} — {plot_file}")
                display(Image(str(plot_path)))

# %% [markdown]
# ## ***Analisis Confusion Pothole***
#
# ---
#
# Section ini menguji hipotesis utama penelitian: **apakah model tanpa negative anchor class
# (manhole & patchy_road) lebih rentan salah mengklasifikasi objek tersebut sebagai Pothole?**
#
# Langkah:
# 1. Kumpulkan gambar test yang ground truth-nya mengandung manhole (ID 4) atau patchy_road (ID 5).
# 2. Jalankan predict model 4-class pada gambar tersebut.
# 3. Hitung berapa prediksi berlabel `Pothole` (ID 3) yang muncul pada gambar-gambar tersebut.
# 4. Hasilnya (`fp_pothole_rate`) dibandingkan secara naratif dengan model 6-class.

# %%
# ── Kumpulkan gambar test yang GT-nya ada manhole (ID 4) atau patchy_road (ID 5) ──
CONFUSION_IDS = {4, 5}   # ID kelas pengecoh di dataset original (6-kelas)
POTHOLE_ID    = 3         # ID Pothole di model 4-class

test_label_dir = DATASET_DIR / "test" / "labels"
confusion_images = []

for lp in sorted(test_label_dir.glob("*.txt")):
    if lp.name.lower() == "classes.txt":
        continue
    for line in lp.read_text(encoding="utf-8", errors="ignore").splitlines():
        parts = line.strip().split()
        if parts and int(parts[0]) in CONFUSION_IDS:
            img_path = DATASET_DIR / "test" / "images" / (lp.stem + ".jpg")
            if not img_path.exists():
                img_path = DATASET_DIR / "test" / "images" / (lp.stem + ".png")
            if img_path.exists():
                confusion_images.append(img_path)
            break  # satu gambar cukup dihitung sekali

confusion_images = list(dict.fromkeys(confusion_images))  # deduplicate, preserve order
print(f"Gambar test yang memuat manhole/patchy_road: {len(confusion_images)}")

# ── Hitung GT object manhole/patchy total pada gambar tersebut ──
n_gt_confusion = 0
for img_path in confusion_images:
    lp = test_label_dir / (img_path.stem + ".txt")
    if lp.exists():
        for line in lp.read_text(encoding="utf-8", errors="ignore").splitlines():
            parts = line.strip().split()
            if parts and int(parts[0]) in CONFUSION_IDS:
                n_gt_confusion += 1

print(f"Total GT object manhole/patchy_road pada gambar tersebut: {n_gt_confusion}")

# ── Predict dan hitung FP Pothole per model ──
PREDICT_CONF_DIR = OUTPUT_DIR / "predictions_confusion_analysis"
confusion_results = {}

for model_name, run_name in trained_runs:
    best_weights = PROJECT_DIR / run_name / "weights/best.pt"
    best_model   = YOLO(str(best_weights))

    preds = best_model.predict(
        source=[str(p) for p in confusion_images],
        imgsz=IMGSZ,
        conf=PRED_CONF,
        iou=PRED_IOU,
        device=DEVICE,
        project=str(PREDICT_CONF_DIR),
        name=f"{model_name}_confusion_analysis",
        exist_ok=True,
        save=False,
        verbose=False,
    )

    n_pred_pothole = sum(
        int((r.boxes.cls == POTHOLE_ID).sum()) for r in preds if r.boxes is not None
    )
    fp_rate = n_pred_pothole / n_gt_confusion if n_gt_confusion > 0 else float("nan")

    confusion_results[model_name] = {
        "n_confusion_images":   len(confusion_images),
        "n_gt_confusion_obj":   n_gt_confusion,
        "n_pred_pothole_on_confusion_imgs": n_pred_pothole,
        "fp_pothole_rate": round(fp_rate, 4),
    }
    print(f"\n{'─'*50}")
    print(f"Model: {model_name}")
    print(f"  Prediksi 'Pothole' pada gambar manhole/patchy : {n_pred_pothole}")
    print(f"  Total GT manhole/patchy                       : {n_gt_confusion}")
    print(f"  FP Pothole rate                               : {fp_rate:.4f}")

    del best_model
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

confusion_df = pd.DataFrame.from_dict(confusion_results, orient="index").reset_index()
confusion_df.columns = ["model", "n_confusion_images", "n_gt_confusion_obj",
                         "n_pred_pothole_on_confusion_imgs", "fp_pothole_rate"]
display(confusion_df)
confusion_df.to_csv(OUTPUT_DIR / "confusion_pothole_analysis.csv", index=False)
print("\nDisimpan ke confusion_pothole_analysis.csv")

# %% [markdown]
# ### ***Prediksi Sampel Test per Model***

# %%
PREDICT_DIR   = OUTPUT_DIR / "predictions"
N_PRED_IMAGES = 6
test_images   = list_images("test")
sample_test   = random.sample(test_images, k=min(N_PRED_IMAGES, len(test_images)))

for model_name, run_name in trained_runs:
    best_weights = PROJECT_DIR / run_name / "weights/best.pt"
    best_model   = YOLO(str(best_weights))

    results = best_model.predict(
        source=[str(p) for p in sample_test],
        imgsz=IMGSZ,
        conf=PRED_CONF,
        iou=PRED_IOU,
        device=DEVICE,
        project=str(PREDICT_DIR),
        name=f"{model_name}_test_samples",
        exist_ok=True,
        save=True,
        save_txt=True,
        save_conf=True,
    )

    print(f"\n{'─'*50}")
    print(f"Model: {model_name} — prediksi sampel test ({PRED_CONF=}, {PRED_IOU=})")
    fig, axes = plt.subplots(2, 3, figsize=(15, 9))
    axes = axes.flatten()
    for ax, r in zip(axes, results):
        ax.imshow(r.plot()[:, :, ::-1])
        ax.set_title(Path(r.path).name[:45])
        ax.axis("off")
    for ax in axes[len(results):]:
        ax.axis("off")
    plt.suptitle(f"{model_name} — prediksi sampel test (4-kelas)")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### ***Confidence Sweep (Opsional)***

# %%
RUN_CONFIDENCE_SWEEP = False
CONF_SWEEP = [0.10, 0.15, 0.20, 0.25, 0.30, 0.40, 0.50]

if RUN_CONFIDENCE_SWEEP:
    for model_name, run_name in trained_runs:
        best_weights = PROJECT_DIR / run_name / "weights/best.pt"
        best_model   = YOLO(str(best_weights))
        rows = []
        for conf in CONF_SWEEP:
            metrics = best_model.val(
                data=str(local_yaml),
                split="test",
                imgsz=IMGSZ,
                batch=BATCH,
                device=DEVICE,
                workers=WORKERS,
                project=str(EVAL_DIR),
                name=f"{model_name}_conf_{conf:.2f}".replace(".", "p"),
                exist_ok=True,
                plots=False,
                save_json=False,
                conf=conf,
                iou=EVAL_IOU,
                verbose=False,
            )
            rows.append({"model": model_name, "conf": conf, **{k: float(v) for k, v in metrics.results_dict.items()}})
        conf_sweep_df = pd.DataFrame(rows)
        display(conf_sweep_df)
        conf_sweep_df.to_csv(OUTPUT_DIR / f"{model_name}_confidence_sweep_test.csv", index=False)
else:
    print("Confidence sweep dilewati. Set RUN_CONFIDENCE_SWEEP=True jika ingin menjalankan.")

# %% [markdown]
# ## ***Template Zero-Shot Bandung***
#
# ---
#
# Jika data primer Bandung sudah diberi label YOLO, buat struktur berikut:
#
# ```
# data/primary_bandung_yolo/
#   data.yaml
#   test/images/
#   test/labels/
# ```
#
# Lalu isi `PRIMARY_DATA_YAML`. Jika data primer belum berlabel, gunakan mode `predict` untuk inspeksi kualitatif.

# %%
PRIMARY_DATA_YAML  = REPO_ROOT / "data/primary_bandung_yolo/data.yaml"
PRIMARY_IMAGES_DIR = REPO_ROOT / "data/primary_bandung_yolo/images"

# Gunakan model terbaik (model pertama di trained_runs) untuk zero-shot.
# Ubah indeks jika ingin model yang berbeda.
if trained_runs:
    zs_model_name, zs_run_name = trained_runs[0]
    zs_weights = PROJECT_DIR / zs_run_name / "weights/best.pt"
    zs_model   = YOLO(str(zs_weights))

    if PRIMARY_DATA_YAML.exists():
        zero_shot_metrics = zs_model.val(
            data=str(PRIMARY_DATA_YAML),
            split="test",
            imgsz=IMGSZ,
            batch=BATCH,
            device=DEVICE,
            workers=WORKERS,
            project=str(EVAL_DIR),
            name=f"{zs_model_name}_zero_shot_bandung",
            exist_ok=True,
            plots=True,
            save_json=True,
            conf=EVAL_CONF,
            iou=EVAL_IOU,
        )
        print(zero_shot_metrics.results_dict)
    else:
        print(f"Belum ada data primer berlabel: {PRIMARY_DATA_YAML}")

    if PRIMARY_IMAGES_DIR.exists():
        bandung_images = sorted([p for p in PRIMARY_IMAGES_DIR.iterdir() if p.suffix.lower() in IMG_EXTS])
        if bandung_images:
            zs_model.predict(
                source=[str(p) for p in bandung_images[:50]],
                imgsz=IMGSZ,
                conf=PRED_CONF,
                iou=PRED_IOU,
                device=DEVICE,
                project=str(PREDICT_DIR),
                name=f"{zs_model_name}_zero_shot_bandung_unlabeled",
                exist_ok=True,
                save=True,
                save_txt=True,
                save_conf=True,
            )
            print(f"Prediksi zero-shot tersimpan di: {PREDICT_DIR / f'{zs_model_name}_zero_shot_bandung_unlabeled'}")
    else:
        print(f"Belum ada folder gambar primer tanpa label: {PRIMARY_IMAGES_DIR}")
else:
    print("trained_runs kosong — jalankan cell training terlebih dahulu.")

# %% [markdown]
# ## ***Output Penting untuk Laporan TA***
#
# ---
#
# Setelah training dan evaluasi selesai, kumpulkan artefak berikut per model:
#
# **Bobot terlatih**
# - `runs/rdd_4class_local/experiments/<model_name>/weights/best.pt`
#
# **Ringkasan metrik**
# - `runs/rdd_4class_local/<model_name>_summary.json`
# - `runs/rdd_4class_local/<model_name>_f1_summary.csv`
# - `runs/rdd_4class_local/<model_name>_val_per_class_metrics.csv`
# - `runs/rdd_4class_local/<model_name>_test_per_class_metrics.csv`
#
# **Analisis confusion pothole**
# - `runs/rdd_4class_local/confusion_pothole_analysis.csv`
#
# **Dataset**
# - `runs/rdd_4class_local/dataset_class_distribution_4cls.csv`
# - `runs/rdd_4class_local/dataset_split_summary_4cls.csv`
#
# **Plot evaluasi** (confusion matrix, PR curve, F1 curve)
# - `runs/rdd_4class_local/evaluation/<model_name>_val/`
# - `runs/rdd_4class_local/evaluation/<model_name>_test/`
#
# **Prediksi sampel**
# - `runs/rdd_4class_local/predictions/<model_name>_test_samples/`
